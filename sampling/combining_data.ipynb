# %% [markdown]
# # Merging Sample with Additional Feature Sets
# This notebook combines the sampled dataset with complementary feature sets available in the Kaggle e-commerce dataset. By joining various related data files, we enrich the sampled client data with additional behavioral and contextual features. The merged dataset is then exported as a Parquet file, which will serve as the main input for subsequent team analyses and modeling tasks.

# %%
import duckdb
import pandas as pd

# %%
# Path to your Parquet file
parquet_path = "data/messages_subset.parquet"

# Connect to DuckDB (in-memory)
con = duckdb.connect()

# Read Parquet file and cast to Pandas DataFrame
messages_df = con.execute(f"SELECT * FROM read_parquet('{parquet_path}')").df()
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[7], line 8
#       5 con = duckdb.connect()
#       7 # Read Parquet file and cast to Pandas DataFrame
# ----> 8 messages_df = con.execute(f"SELECT * FROM read_parquet('{parquet_path}')").df()
#
# IOException: IO Error: No files found that match the pattern "data/messages_subset.parquet"
#
# LINE 1: SELECT * FROM read_parquet('data/messages_subset.parquet')
#                       ^

# %%
campaigns_df = pd.read_csv('data/campaigns.csv')
first_purchase_df = pd.read_csv('data/client_first_purchase_date.csv')
holidays_df = pd.read_csv('data/holidays.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 campaigns_df = pd.read_csv('data/campaigns.csv')
#       2 first_purchase_df = pd.read_csv('data/client_first_purchase_date.csv')
#       3 holidays_df = pd.read_csv('data/holidays.csv')
#
# File ~/Documents/BSE/Economics_DecisionMaking/Capstone/message-campaign-engagement-analysis/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Documents/BSE/Economics_DecisionMaking/Capstone/message-campaign-engagement-analysis/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Documents/BSE/Economics_DecisionMaking/Capstone/message-campaign-engagement-analysis/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Documents/BSE/Economics_DecisionMaking/Capstone/message-campaign-engagement-analysis/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Documents/BSE/Economics_DecisionMaking/Capstone/message-campaign-engagement-analysis/.venv/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/campaigns.csv'

# %%
messages_df.columns
# Out:
# Index(['id', 'message_id', 'campaign_id', 'message_type', 'client_id',
#        'channel', 'category', 'platform', 'email_provider', 'stream', 'date',
#        'sent_at', 'is_opened', 'opened_first_time_at', 'opened_last_time_at',
#        'is_clicked', 'clicked_first_time_at', 'clicked_last_time_at',
#        'is_unsubscribed', 'unsubscribed_at', 'is_hard_bounced',
#        'hard_bounced_at', 'is_soft_bounced', 'soft_bounced_at',
#        'is_complained', 'complained_at', 'is_blocked', 'blocked_at',
#        'is_purchased', 'purchased_at', 'created_at', 'updated_at'],
#       dtype='object')

# %%
campaigns_df.columns
# Out:
# Index(['id', 'campaign_type', 'channel', 'topic', 'started_at', 'finished_at',
#        'total_count', 'ab_test', 'warmup_mode', 'hour_limit', 'subject_length',
#        'subject_with_personalization', 'subject_with_deadline',
#        'subject_with_emoji', 'subject_with_bonuses', 'subject_with_discount',
#        'subject_with_saleout', 'is_test', 'position'],
#       dtype='object')

# %%
first_purchase_df.columns
# Out:
# Index(['client_id', 'first_purchase_date'], dtype='object')

# %%
holidays_df.columns
# Out:
# Index(['date', 'holiday'], dtype='object')

# %%
messages_df.merge(campaigns_df.rename(columns = {'id' : 'campaign_id'}), on='campaign_id', how='left').head()
# Out:
#           id                               message_id  campaign_id  \
# 0  689791327  1515915625489087633-11387-64244e6bd4d4e        11387
# 1  689792401  1515915625489107288-11387-64244e6bd72d3        11387
# 2  689792664  1515915625489112445-11387-64244e6bd81d6        11387
# 3  689793297  1515915625489122538-11387-64244e6bd98c2        11387
# 4  689793902  1515915625489133634-11387-64244e6bdb2a6        11387
#
#   message_type            client_id    channel_x category platform  \
# 0         bulk  1515915625489087633  mobile_push     None     None
# 1         bulk  1515915625489107288  mobile_push     None     None
# 2         bulk  1515915625489112445  mobile_push     None     None
# 3         bulk  1515915625489122538  mobile_push     None     None
# 4         bulk  1515915625489133634  mobile_push     None     None
#
#   email_provider   stream  ... hour_limit subject_length  \
# 0           None  desktop  ...        NaN           30.0
# 1           None  desktop  ...        NaN           30.0
# 2           None  desktop  ...        NaN           30.0
# 3           None  desktop  ...        NaN           30.0
# 4           None  desktop  ...        NaN           30.0
#
#    subject_with_personalization subject_with_deadline subject_with_emoji  \
# 0                         False                 False               True
# 1                         False                 False               True
# 2                         False                 False               True
# 3                         False                 False               True
# 4                         False                 False               True
#
#    subject_with_bonuses subject_with_discount subject_with_saleout  is_test  \
# 0                 False                 False                False      NaN
# 1                 False                 False                False      NaN
# 2                 False                 False                False      NaN
# 3                 False                 False                False      NaN
# 4                 False                 False                False      NaN
#
#   position
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
# [5 rows x 50 columns]

# %%
messages_df = messages_df.merge(campaigns_df.rename(columns = {'id' : 'campaign_id'}), on='campaign_id', how='left')

# %%
messages_df.merge(first_purchase_df, on='client_id', how='left').iloc[:,-1].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: first_purchase_date, dtype: object

# %%
messages_df = messages_df.merge(first_purchase_df, on='client_id', how='left')

# %%
holidays_df['date'].head()
# Out:
# 0    2021-01-01
# 1    2021-01-07
# 2    2021-01-13
# 3    2021-01-19
# 4    2021-01-25
# Name: date, dtype: object

# %%
messages_df.date.head()
# Out:
# 0   2023-03-29
# 1   2023-03-29
# 2   2023-03-29
# 3   2023-03-29
# 4   2023-03-29
# Name: date, dtype: datetime64[us]

# %%
messages_df['date'] = messages_df['date'].dt.date
messages_df.merge(holidays_df, on='date', how='left').iloc[:,-1].unique()
# Out:
# array([nan], dtype=object)

# %% [markdown]
# Campaigns are sent before holidays, that is why none of the holidays has merged to the dataframe. We can calculate days before/after holiday that can be used as a feature.

# %%
messages_df.shape
# Out:
# (1686884, 51)

# %%
# save the combined dataframe
messages_df.to_parquet('data/combined_dataset.parquet')

# %%
messages_df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1686884 entries, 0 to 1686883
# Data columns (total 51 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   id                            1686884 non-null  int64
#  1   message_id                    1686884 non-null  object
#  2   campaign_id                   1686884 non-null  int64
#  3   message_type                  1686884 non-null  object
#  4   client_id                     1686884 non-null  int64
#  5   channel_x                     1686884 non-null  object
#  6   category                      0 non-null        object
#  7   platform                      247181 non-null   object
#  8   email_provider                1074538 non-null  object
#  9   stream                        1686884 non-null  object
#  10  date                          1686465 non-null  object
#  11  sent_at                       1686465 non-null  datetime64[us]
#  12  is_opened                     1686884 non-null  bool
#  13  opened_first_time_at          315943 non-null   datetime64[us]
#  14  opened_last_time_at           315943 non-null   datetime64[us]
#  15  is_clicked                    1686884 non-null  bool
#  16  clicked_first_time_at         17865 non-null    datetime64[us]
#  17  clicked_last_time_at          17865 non-null    datetime64[us]
#  18  is_unsubscribed               1686884 non-null  bool
#  19  unsubscribed_at               4037 non-null     datetime64[us]
#  20  is_hard_bounced               1686884 non-null  bool
#  21  hard_bounced_at               11769 non-null    datetime64[us]
#  22  is_soft_bounced               1686884 non-null  bool
#  23  soft_bounced_at               3832 non-null     datetime64[us]
#  24  is_complained                 1686884 non-null  bool
#  25  complained_at                 339 non-null      datetime64[us]
#  26  is_blocked                    1686884 non-null  bool
#  27  blocked_at                    218 non-null      object
#  28  is_purchased                  1686884 non-null  bool
#  29  purchased_at                  616 non-null      datetime64[us]
#  30  created_at                    1686884 non-null  datetime64[us]
#  31  updated_at                    1686884 non-null  datetime64[us]
#  32  campaign_type                 1686884 non-null  object
#  33  channel_y                     1686884 non-null  object
#  34  topic                         1664462 non-null  object
#  35  started_at                    1558881 non-null  object
#  36  finished_at                   1534425 non-null  object
#  37  total_count                   1558881 non-null  float64
#  38  ab_test                       8940 non-null     object
#  39  warmup_mode                   1563273 non-null  object
#  40  hour_limit                    26136 non-null    float64
#  41  subject_length                1601620 non-null  float64
#  42  subject_with_personalization  1601620 non-null  object
#  43  subject_with_deadline         1601620 non-null  object
#  44  subject_with_emoji            1601620 non-null  object
#  45  subject_with_bonuses          1601620 non-null  object
#  46  subject_with_discount         1601620 non-null  object
#  47  subject_with_saleout          1601620 non-null  object
#  48  is_test                       85264 non-null    object
#  49  position                      85260 non-null    float64
#  50  first_purchase_date           345783 non-null   object
# dtypes: bool(8), datetime64[us](12), float64(4), int64(3), object(24)
# memory usage: 1.9 GB

# %% [markdown]
# As Pandas Dataframe the dataset use 1.9 gb of memory.
